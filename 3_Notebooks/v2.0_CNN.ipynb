# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
import numpy as np
import missingno

from IPython.display import display

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, fbeta_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from category_encoders import BinaryEncoder

import tensorflow
from tensorflow.keras import optimizers, Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Dense, Input, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dropout, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard

# %%
df = pd.read_csv("train_data.csv")
timestep = 12 #from 1 to 23 (17 with the current NaN strategy)
threshold_for_classification = -6.5
fill_X = -0.01
X_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()
seed = 11

#RNN hiperparameter
epochs = 50
batch = 64
val_split = 0.25
test_split = 0.25
adam = optimizers.Nadam(learning_rate=0.001) #(lr)
class_weight = {True:  100.,
                False: 1.}
verbose = 1

# %%
#Dropping first the empty column and then rows with NaNs
df = df.drop("c_rcs_estimate", axis=1)
df = df.dropna(how='any')

#Filtering events with len=1 or min_tca > 2 or max_tca < 2
def conditions(event):
    x = event["time_to_tca"].values
    return ((x.min()<2.0) & (x.max()>2.0) & (x.shape[0]>1))
df = df.groupby('event_id').filter(conditions)

#OHE for c_object_type (5 categories) -> 5 new features
df["mission_id"] = df["mission_id"].astype('category')
df["c_object_type"] = df["c_object_type"].astype('category')
df = pd.get_dummies(df)

#Getting y as 1D-array
y = df.groupby(["event_id"])["risk"].apply(lambda x: x.iloc[-1]).values.reshape(-1, 1)

#Scaling y
_ = y_scaler.fit(df["risk"].values.reshape(-1, 1)) #using the whole risk feature to scale the target 'y'
y = y_scaler.transform(y)

#Getting X as df (dropping rows with tca < 2) 
df = df.loc[df["time_to_tca"]>2]

#Adding feature 'event_length' for counting how many instances each event has
df["event_length"] = df.groupby('event_id')['event_id'].transform('value_counts')

#Scaling X
df = pd.DataFrame(X_scaler.fit_transform(df), columns=df.columns)

#Transforming X into a 3D-array
events = df["event_id"].nunique() #rows
features = len(df.columns) #columns

X = np.zeros((events,timestep,features))
X.fill(fill_X)

i = 0
def df_to_3darray(event):
    global X, i
    #Transforming an event to time series (1,timesteps, columns)
    row = event.values.reshape(1,event.shape[0],event.shape[1])
    #Condition is needed to slice arrays correctly
    #Condition -> is timestep greater than the event's time series length? 
    if(timestep>=row.shape[1]):
        X[i:i+1,-row.shape[1]:,:] = row
    else:
        X[i:i+1,:,:] = row[:,-timestep:,:]
    #index to iterate over X array
    i = i + 1
    #dataframe remains intact, while X array has been filled.
    return event

df.groupby("event_id").apply(df_to_3darray)

#Dropping event_id to remove noise
X = X[:,:,1:]

#TODO: Padding with specific values column-wise instead of zeros.
#TODO: Separating time dependent and independent feature in 2 X arrays

print(X.shape, y.shape)
# Out:
# (7311, 12, 124) (7311, 1)

# %%
#computing scaled threshold 
th = np.array([threshold_for_classification]).reshape(-1,1)
th = y_scaler.transform(th)
threshold_scaled = th[0,0]

#Splitting arrays
y_boolean = (y > threshold_scaled).reshape(-1,1)
X_train, X_test, y_train_numeric, y_test_numeric = train_test_split(X, y, 
                                                    stratify=y_boolean, 
                                                    shuffle=True,
                                                    random_state=seed,
                                                    test_size = test_split
                                                  )

y_train_boolean = (y_train_numeric > threshold_scaled).reshape(-1,1)
X_train, X_val, y_train_numeric, y_val_numeric = train_test_split(X_train, y_train_numeric, 
                                                    stratify=y_train_boolean, 
                                                    shuffle=True,
                                                    random_state=seed,
                                                    test_size = val_split
                                                  )
#transforming it into a classification task -> y_train, y_test boolean
y_train = (y_train_numeric > threshold_scaled).reshape(-1,1)
y_val = (y_val_numeric > threshold_scaled).reshape(-1,1)
y_test = (y_test_numeric > threshold_scaled).reshape(-1,1)

#Percentage of high risks in train
print("TRAIN {:0.1f}, {:0.1f}, {:0.3f}".format(np.sum(y_train), y_train.shape[0], np.sum(y_train)/y_train.shape[0]))
#Percentage of high risks in val
print("VAL   {:0.1f}, {:0.1f}, {:0.3f}".format(np.sum(y_val), y_val.shape[0], np.sum(y_val)/y_val.shape[0]))
#Percentage of high risks in test
print("TEST  {:0.1f}, {:0.1f}, {:0.3f}".format(np.sum(y_test), y_test.shape[0], np.sum(y_test)/y_test.shape[0]))
# Out:
# TRAIN 73.0, 4112.0, 0.018
# VAL   24.0, 1371.0, 0.018
# TEST  33.0, 1828.0, 0.018

# %%
# Model
model = Sequential()

model.add(Input(batch_shape=(batch, X_train.shape[1], X_train.shape[2])))
model.add(Conv1D(10, 3, activation='relu'))
model.add(Conv1D(10, 3, activation='relu'))
model.add(MaxPooling1D(2))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (64, 10, 10)              3730
# _________________________________________________________________
# conv1d_3 (Conv1D)            (64, 8, 10)               310
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (64, 4, 10)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (64, 4, 10)               0
# _________________________________________________________________
# flatten_1 (Flatten)          (64, 40)                  0
# _________________________________________________________________
# dense_2 (Dense)              (64, 8)                   328
# _________________________________________________________________
# dense_3 (Dense)              (64, 1)                   9
# =================================================================
# Total params: 4,377
# Trainable params: 4,377
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history = model.fit(X_train, y_train, 
                          epochs=epochs, 
                          batch_size=batch, 
                          shuffle=True, 
                          validation_data=(X_val, y_val),
                          verbose=verbose,
                          class_weight=class_weight
                         ).history
# Out:
# Train on 4112 samples, validate on 1371 samples
# Epoch 1/50
# 4112/4112 [==============================] - 1s 323us/sample - loss: 1.8506 - accuracy: 0.2748 - val_loss: 1.7580 - val_accuracy: 0.3786
# Epoch 2/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 1.6200 - accuracy: 0.4227 - val_loss: 1.6870 - val_accuracy: 0.1670
# Epoch 3/50
# 4112/4112 [==============================] - 0s 68us/sample - loss: 1.4331 - accuracy: 0.5032 - val_loss: 1.5431 - val_accuracy: 0.5135
# Epoch 4/50
# 4112/4112 [==============================] - 0s 66us/sample - loss: 1.2891 - accuracy: 0.5756 - val_loss: 1.5404 - val_accuracy: 0.5770
# Epoch 5/50
# 4112/4112 [==============================] - 0s 68us/sample - loss: 1.1982 - accuracy: 0.6420 - val_loss: 1.6864 - val_accuracy: 0.6915
# Epoch 6/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 1.1720 - accuracy: 0.6493 - val_loss: 1.7009 - val_accuracy: 0.6302
# Epoch 7/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 1.0542 - accuracy: 0.6892 - val_loss: 2.2954 - val_accuracy: 0.8337
# Epoch 8/50
# 4112/4112 [==============================] - 0s 65us/sample - loss: 1.0009 - accuracy: 0.7028 - val_loss: 2.0803 - val_accuracy: 0.7578
# Epoch 9/50
# 4112/4112 [==============================] - 0s 66us/sample - loss: 0.8911 - accuracy: 0.7408 - val_loss: 2.4838 - val_accuracy: 0.8125
# Epoch 10/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 0.9345 - accuracy: 0.7264 - val_loss: 2.2579 - val_accuracy: 0.7593
# Epoch 11/50
# 4112/4112 [==============================] - 0s 66us/sample - loss: 0.8362 - accuracy: 0.7532 - val_loss: 2.7225 - val_accuracy: 0.8206
# Epoch 12/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 0.7886 - accuracy: 0.7738 - val_loss: 2.5433 - val_accuracy: 0.7309
# Epoch 13/50
# 4112/4112 [==============================] - 0s 66us/sample - loss: 0.6898 - accuracy: 0.7899 - val_loss: 3.0271 - val_accuracy: 0.6273
# Epoch 14/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 0.9883 - accuracy: 0.7225 - val_loss: 3.2103 - val_accuracy: 0.8177
# Epoch 15/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 0.6662 - accuracy: 0.8115 - val_loss: 3.8545 - val_accuracy: 0.8381
# Epoch 16/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 0.6779 - accuracy: 0.8093 - val_loss: 3.6016 - val_accuracy: 0.8155
# Epoch 17/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 0.6258 - accuracy: 0.8247 - val_loss: 3.9069 - val_accuracy: 0.8198
# Epoch 18/50
# 4112/4112 [==============================] - 0s 72us/sample - loss: 0.6059 - accuracy: 0.8354 - val_loss: 3.5739 - val_accuracy: 0.6652
# Epoch 19/50
# 4112/4112 [==============================] - 0s 72us/sample - loss: 0.6121 - accuracy: 0.8181 - val_loss: 4.0308 - val_accuracy: 0.8235
# Epoch 20/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 0.6170 - accuracy: 0.8222 - val_loss: 4.7787 - val_accuracy: 0.8636
# Epoch 21/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 0.5598 - accuracy: 0.8444 - val_loss: 5.2767 - val_accuracy: 0.8709
# Epoch 22/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 0.5415 - accuracy: 0.8572 - val_loss: 4.0255 - val_accuracy: 0.7724
# Epoch 23/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 0.6246 - accuracy: 0.8278 - val_loss: 4.3928 - val_accuracy: 0.8118
# Epoch 24/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 0.5688 - accuracy: 0.8439 - val_loss: 6.3270 - val_accuracy: 0.8877
# Epoch 25/50
# 4112/4112 [==============================] - 0s 69us/sample - loss: 0.5005 - accuracy: 0.8575 - val_loss: 5.8108 - val_accuracy: 0.8804
# Epoch 26/50
# 4112/4112 [==============================] - 0s 66us/sample - loss: 0.7098 - accuracy: 0.8096 - val_loss: 5.3564 - val_accuracy: 0.8643
# Epoch 27/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 0.4788 - accuracy: 0.8723 - val_loss: 4.7380 - val_accuracy: 0.7921
# Epoch 28/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 0.5145 - accuracy: 0.8538 - val_loss: 6.6009 - val_accuracy: 0.9125
# Epoch 29/50
# 4112/4112 [==============================] - 0s 72us/sample - loss: 0.4782 - accuracy: 0.8740 - val_loss: 9.1030 - val_accuracy: 0.9511
# Epoch 30/50
# 4112/4112 [==============================] - 0s 71us/sample - loss: 0.5503 - accuracy: 0.8621 - val_loss: 6.5039 - val_accuracy: 0.8818
# Epoch 31/50
# 4112/4112 [==============================] - 0s 69us/sample - loss: 0.4350 - accuracy: 0.8855 - val_loss: 7.6663 - val_accuracy: 0.9161
# Epoch 32/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 0.4727 - accuracy: 0.8757 - val_loss: 8.0846 - val_accuracy: 0.9227
# Epoch 33/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 0.6493 - accuracy: 0.8356 - val_loss: 5.0644 - val_accuracy: 0.8395
# Epoch 34/50
# 4112/4112 [==============================] - 0s 70us/sample - loss: 0.5652 - accuracy: 0.8346 - val_loss: 5.9767 - val_accuracy: 0.8760
# Epoch 35/50
# 4112/4112 [==============================] - 0s 71us/sample - loss: 0.4652 - accuracy: 0.8796 - val_loss: 5.6037 - val_accuracy: 0.8651
# Epoch 36/50
# 4112/4112 [==============================] - 0s 71us/sample - loss: 0.6109 - accuracy: 0.8444 - val_loss: 5.6443 - val_accuracy: 0.8607
# Epoch 37/50
# 4112/4112 [==============================] - 0s 68us/sample - loss: 0.4543 - accuracy: 0.8704 - val_loss: 7.6154 - val_accuracy: 0.9139
# Epoch 38/50
# 4112/4112 [==============================] - 0s 70us/sample - loss: 0.4405 - accuracy: 0.8813 - val_loss: 7.2061 - val_accuracy: 0.8928
# Epoch 39/50
# 4112/4112 [==============================] - 0s 70us/sample - loss: 0.3870 - accuracy: 0.8964 - val_loss: 8.1081 - val_accuracy: 0.9088
# Epoch 40/50
# 4112/4112 [==============================] - 0s 69us/sample - loss: 0.4983 - accuracy: 0.8765 - val_loss: 5.9788 - val_accuracy: 0.8074
# Epoch 41/50
# 4112/4112 [==============================] - 0s 71us/sample - loss: 0.4771 - accuracy: 0.8704 - val_loss: 8.6635 - val_accuracy: 0.9292
# Epoch 42/50
# 4112/4112 [==============================] - 0s 71us/sample - loss: 0.3807 - accuracy: 0.8976 - val_loss: 5.9069 - val_accuracy: 0.8082
# Epoch 43/50
# 4112/4112 [==============================] - 0s 73us/sample - loss: 0.4483 - accuracy: 0.8794 - val_loss: 10.0848 - val_accuracy: 0.9307
# Epoch 44/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 0.4243 - accuracy: 0.8896 - val_loss: 9.1707 - val_accuracy: 0.9168
# Epoch 45/50
# 4112/4112 [==============================] - 0s 67us/sample - loss: 0.3954 - accuracy: 0.8957 - val_loss: 6.6754 - val_accuracy: 0.8286
# Epoch 46/50
# 4112/4112 [==============================] - 0s 68us/sample - loss: 0.4047 - accuracy: 0.8874 - val_loss: 10.3477 - val_accuracy: 0.9336
# Epoch 47/50
# 4112/4112 [==============================] - 0s 68us/sample - loss: 0.5306 - accuracy: 0.8619 - val_loss: 7.3807 - val_accuracy: 0.8869
# Epoch 48/50
# 4112/4112 [==============================] - 0s 68us/sample - loss: 0.3952 - accuracy: 0.9018 - val_loss: 7.1176 - val_accuracy: 0.8585
# Epoch 49/50
# 4112/4112 [==============================] - 0s 74us/sample - loss: 0.4041 - accuracy: 0.8774 - val_loss: 8.3304 - val_accuracy: 0.8935
# Epoch 50/50
# 4112/4112 [==============================] - 0s 71us/sample - loss: 0.3717 - accuracy: 0.9010 - val_loss: 9.1237 - val_accuracy: 0.8986

# %%
sns.set()

for graph in ['loss', 'accuracy']:
    
    plt.plot(model_history[graph], linewidth=2, label='Train')
    plt.plot(model_history['val_'+graph], linewidth=2, label='Valid')
    
    plt.legend(loc='upper right')
    plt.title('Model '+graph)
    plt.ylabel(graph)
    plt.xlabel('Epoch')
    
    plt.show()

# %%
#Model Evaluation
high_risk_real_value = -5.0
low_risk_real_value  = -6.0001
classification_threshold = 0.955

def evaluate(name, y_pred):
    
    #rescaling data
    y_test_scaled = y_scaler.inverse_transform(y_test_numeric)
    
    #getting numeric predictions from boolean predictions
    y_pred_numeric = np.zeros((y_pred.shape[0],y_pred.shape[1]))
    y_pred_numeric[y_pred==True] = high_risk_real_value
    y_pred_numeric[y_pred==False] = low_risk_real_value
    
    #getting predictions greater than -6.0 in real data (y_test_scaled)
    y_pred_mse = y_pred_numeric[np.where(y_test_scaled >= -6.0)]
    y_test_mse = y_test_scaled[np.where(y_test_scaled >= -6.0)]
    
    mse = mean_squared_error(y_test_mse, y_pred_mse)
    
    y_real_bool = (y_test_scaled >= -6.0).reshape(-1,1)
    
    f_beta = fbeta_score(y_real_bool, y_pred, 2)
    score = mse / f_beta
    print(name, "{:0.3f}, {:0.3f}, {:0.3f}".format(score, mse, f_beta))
        
    hm = sns.heatmap(confusion_matrix(y_real_bool, y_pred), annot=True, cmap="Blues", fmt='d')# font size
    bottom, top = hm.get_ylim()
    hm.set_ylim(bottom + 0.5, top - 0.5)
    plt.show()

#Predicting with model
y_model = model.predict(X_test, batch_size=batch)
plt.hist(y_model, bins=30)
plt.show()
y_model = (y_model > classification_threshold).reshape(-1,1)
evaluate("LSTM model:", y_model)

#Predicting -5 always
y_constant = np.ones((y_test.shape[0],y_test.shape[1]), dtype=bool)
evaluate("Constant prediction:", y_constant)

#Predicting last value
y_last = X_test[:,-1,1]
tmp = np.array([-6]).reshape(-1,1)
tmp = y_scaler.transform(tmp)
tmp = tmp[0,0]
y_last = (y_last > tmp).reshape(-1,1)
evaluate("Predicting last value:", y_last)
# Out:
# LSTM model: 0.891, 0.345, 0.388
# Constant prediction: 6.819, 0.340, 0.050
# Predicting last value: 0.600, 0.372, 0.620

# %%
#Predicting last value
def recurrent_evaluate(name, y_pred):
    
    #Scaling both real predicted
    y_pred_scaled = y_scaler.inverse_transform(y_pred)
    y_real_scaled = y_scaler.inverse_transform(y_test_numeric)
    
    #boolean data
    y_pred_bool = (y_pred_scaled >= -6.0).reshape(-1,1)
    y_real_bool = (y_real_scaled >= -6.0).reshape(-1,1)
    f_beta = fbeta_score(y_real_bool, y_pred_bool, 2)
    
    #getting predictions greater than -6.0 in real data (y_real_scaled)
    y_pred_mse = y_pred_scaled[np.where(y_real_scaled >= -6.0)]
    y_real_mse = y_real_scaled[np.where(y_real_scaled >= -6.0)]
    mse = mean_squared_error(y_real_mse, y_pred_mse)
    
    #F-beta score
    score = mse / f_beta
    print(name, "{:0.3f}, {:0.3f}, {:0.3f}".format(score, mse, f_beta))
        
    #Confusion matrix
    hm = sns.heatmap(confusion_matrix(y_real_bool, y_pred_bool), annot=True, cmap="Blues", fmt='d')# font size
    bottom, top = hm.get_ylim()
    hm.set_ylim(bottom + 0.5, top - 0.5)
    plt.show()

    
y_last = X_test[:,-1,1].reshape(-1,1)
y_bool_2 = recurrent_evaluate("Predicting last value:", y_last)
# Out:
# Predicting last value: 15.029, 9.324, 0.620
