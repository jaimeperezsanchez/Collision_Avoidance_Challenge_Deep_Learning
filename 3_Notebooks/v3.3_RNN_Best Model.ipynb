# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
import numpy as np
import missingno

from IPython.display import display

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, fbeta_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from category_encoders import BinaryEncoder

import tensorflow
from tensorflow.keras import optimizers, Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Dense, LSTM, RepeatVector, TimeDistributed, Input, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from tensorflow.keras.regularizers import L1L2

# %%
df = pd.read_csv("train_data.csv")
timestep = 8 #from 1 to 23 (17 with the current NaN strategy)
threshold_for_classification = -6.5
X_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()
fill_X = -0.01
seed = 11
features = ['event_id','time_to_tca', 'risk', 'c_time_lastob_end', 
             'c_time_lastob_start', 'max_risk_estimate',
             'max_risk_scaling']

#RNN hiperparameter
epochs = 100
batch = 256
val_split = 0.25
test_split = 0.25
lr = 0.0001
adam = optimizers.Adam() #(lr)
class_weight = {True:  300.,
                False: 1.}
verbose = 1

# %%
#Dropping first the empty column and then rows with NaNs
df = df.drop("c_rcs_estimate", axis=1)
df = df.dropna(how='any')

#Filtering events with len=1 or min_tca > 2 or max_tca < 2
def conditions(event):
    x = event["time_to_tca"].values
    return ((x.min()<2.0) & (x.max()>2.0) & (x.shape[0]>1))
df = df.groupby('event_id').filter(conditions)

#OHE for c_object_type (5 categories) -> 5 new features
df["mission_id"] = df["mission_id"].astype('category')
df["c_object_type"] = df["c_object_type"].astype('category')
df = pd.get_dummies(df)

#Getting y as 1D-array
y = df.groupby(["event_id"])["risk"].apply(lambda x: x.iloc[-1]).values.reshape(-1, 1)

#Scaling y
_ = y_scaler.fit(df["risk"].values.reshape(-1, 1)) #using the whole risk feature to scale the target 'y'
y = y_scaler.transform(y)

#Getting X as df (dropping rows with tca < 2) 
df = df.loc[df["time_to_tca"]>2]

#Scaling X
df = pd.DataFrame(X_scaler.fit_transform(df), columns=df.columns)

df = df[features]

#Transforming X into a 3D-array
events = df["event_id"].nunique() #rows
features = len(df.columns) #columns

X = np.zeros((events,timestep,features))
X.fill(fill_X)

i = 0
def df_to_3darray(event):
    global X, i
    #Transforming an event to time series (1,timesteps, columns)
    row = event.values.reshape(1,event.shape[0],event.shape[1])
    #Condition is needed to slice arrays correctly
    #Condition -> is timestep greater than the event's time series length? 
    if(timestep>=row.shape[1]):
        X[i:i+1,-row.shape[1]:,:] = row
    else:
        X[i:i+1,:,:] = row[:,-timestep:,:]
    #index to iterate over X array
    i = i + 1
    #dataframe remains intact, while X array has been filled.
    return event

df.groupby("event_id").apply(df_to_3darray)

#Dropping event_id to remove noise
X = X[:,:,1:]

#TODO: Padding with specific values column-wise instead of zeros.
#TODO: Separating time dependent and independent feature in 2 X arrays

print(X.shape, y.shape)
# Out:
# (7311, 8, 6) (7311, 1)

# %%
#computing scaled threshold 
th = np.array([threshold_for_classification]).reshape(-1,1)
th = y_scaler.transform(th)
threshold_scaled = th[0,0]

#Splitting arrays
y_boolean = (y > threshold_scaled).reshape(-1,1)
X_train, X_test, y_train_numeric, y_test_numeric = train_test_split(X, y, 
                                                    stratify=y_boolean, 
                                                    shuffle=True,
                                                    random_state=seed,
                                                    test_size = test_split
                                                  )

y_train_boolean = (y_train_numeric > threshold_scaled).reshape(-1,1)
X_train, X_val, y_train_numeric, y_val_numeric = train_test_split(X_train, y_train_numeric, 
                                                    stratify=y_train_boolean, 
                                                    shuffle=True,
                                                    random_state=seed,
                                                    test_size = val_split
                                                  )
#transforming it into a classification task -> y_train, y_test boolean
y_train = (y_train_numeric > threshold_scaled).reshape(-1,1)
y_val = (y_val_numeric > threshold_scaled).reshape(-1,1)
y_test = (y_test_numeric > threshold_scaled).reshape(-1,1)

#Percentage of high risks in train
print("TRAIN {:0.1f}, {:0.1f}, {:0.3f}".format(np.sum(y_train), y_train.shape[0], np.sum(y_train)/y_train.shape[0]))
#Percentage of high risks in val
print("VAL   {:0.1f}, {:0.1f}, {:0.3f}".format(np.sum(y_val), y_val.shape[0], np.sum(y_val)/y_val.shape[0]))
#Percentage of high risks in test
print("TEST  {:0.1f}, {:0.1f}, {:0.3f}".format(np.sum(y_test), y_test.shape[0], np.sum(y_test)/y_test.shape[0]))
# Out:
# TRAIN 73.0, 4112.0, 0.018
# VAL   24.0, 1371.0, 0.018
# TEST  33.0, 1828.0, 0.018

# %%
# Model activation selu
input_tensor = Input(batch_shape=(batch, timestep, X_train.shape[2]))
rnn_1 = LSTM(50, stateful=False, dropout=0.1, recurrent_dropout=0.2, return_sequences=True, kernel_regularizer=L1L2(l1=0.0, l2=0.001))(input_tensor)
batch_1 = BatchNormalization()(rnn_1)
rnn_2 = LSTM(25, stateful=False, dropout=0.1, recurrent_dropout=0.2, return_sequences=True, kernel_regularizer=L1L2(l1=0.0, l2=0.001))(batch_1)
batch_2 = BatchNormalization()(rnn_2)
rnn_3 = LSTM(12, stateful=False, dropout=0.1, recurrent_dropout=0.2, return_sequences=True, kernel_regularizer=L1L2(l1=0.0, l2=0.001))(batch_2)
batch_3 = BatchNormalization()(rnn_3)
rnn_4 = LSTM(5, stateful=False, dropout=0.1, recurrent_dropout=0.2, return_sequences=False, kernel_regularizer=L1L2(l1=0.0, l2=0.001))(batch_2)
batch_4 = BatchNormalization()(rnn_4)
output_tensor = Dense(units = 1, activation='sigmoid')(batch_4)

model = Model(inputs=input_tensor,
              outputs= output_tensor)

model.compile(loss='binary_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(256, 8, 6)]             0
# _________________________________________________________________
# lstm_8 (LSTM)                (256, 8, 50)              11400
# _________________________________________________________________
# batch_normalization_8 (Batch (256, 8, 50)              200
# _________________________________________________________________
# lstm_9 (LSTM)                (256, 8, 25)              7600
# _________________________________________________________________
# batch_normalization_9 (Batch (256, 8, 25)              100
# _________________________________________________________________
# lstm_11 (LSTM)               (256, 5)                  620
# _________________________________________________________________
# batch_normalization_11 (Batc (256, 5)                  20
# _________________________________________________________________
# dense_2 (Dense)              (256, 1)                  6
# =================================================================
# Total params: 19,946
# Trainable params: 19,786
# Non-trainable params: 160
# _________________________________________________________________

# %%
model_history = model.fit(X_train, y_train, 
                          epochs=epochs, 
                          batch_size=batch, 
                          #shuffle=True, #OJO
                          validation_data=(X_val, y_val),
                          verbose=verbose,
                          class_weight=class_weight
                         ).history
# Out:
# Train on 4112 samples, validate on 1371 samples
# Epoch 1/100
# 4112/4112 [==============================] - 5s 1ms/sample - loss: 4.6330 - accuracy: 0.4949 - val_loss: 4.2889 - val_accuracy: 0.6616
# Epoch 2/100
# 4112/4112 [==============================] - 0s 94us/sample - loss: 2.9427 - accuracy: 0.4433 - val_loss: 4.2068 - val_accuracy: 0.7097
# Epoch 3/100
# 4112/4112 [==============================] - 0s 94us/sample - loss: 2.0294 - accuracy: 0.4528 - val_loss: 4.1749 - val_accuracy: 0.7834
# Epoch 4/100
# 4112/4112 [==============================] - 0s 95us/sample - loss: 1.8307 - accuracy: 0.4715 - val_loss: 4.1702 - val_accuracy: 0.8038
# Epoch 5/100
# 4112/4112 [==============================] - 0s 94us/sample - loss: 2.0376 - accuracy: 0.4769 - val_loss: 4.0838 - val_accuracy: 0.7586
# Epoch 6/100
# 4112/4112 [==============================] - 0s 97us/sample - loss: 1.9108 - accuracy: 0.4718 - val_loss: 4.0018 - val_accuracy: 0.7163
# Epoch 7/100
# 4112/4112 [==============================] - 0s 95us/sample - loss: 2.0430 - accuracy: 0.4954 - val_loss: 4.0678 - val_accuracy: 0.7505
# Epoch 8/100
# 4112/4112 [==============================] - 0s 97us/sample - loss: 1.9824 - accuracy: 0.5046 - val_loss: 4.0147 - val_accuracy: 0.7542
# Epoch 9/100
# 4112/4112 [==============================] - 0s 105us/sample - loss: 1.8532 - accuracy: 0.5058 - val_loss: 3.8980 - val_accuracy: 0.7622
# Epoch 10/100
# 4112/4112 [==============================] - 0s 97us/sample - loss: 2.0048 - accuracy: 0.5032 - val_loss: 3.9562 - val_accuracy: 0.8016
# Epoch 11/100
# 4112/4112 [==============================] - 0s 96us/sample - loss: 2.0225 - accuracy: 0.5085 - val_loss: 4.0524 - val_accuracy: 0.8213
# Epoch 12/100
# 4112/4112 [==============================] - 0s 96us/sample - loss: 1.8001 - accuracy: 0.5122 - val_loss: 4.1796 - val_accuracy: 0.8439
# Epoch 13/100
# 4112/4112 [==============================] - 0s 94us/sample - loss: 1.8304 - accuracy: 0.5131 - val_loss: 4.4514 - val_accuracy: 0.8658
# Epoch 14/100
# 4112/4112 [==============================] - 0s 97us/sample - loss: 1.8450 - accuracy: 0.5187 - val_loss: 4.7481 - val_accuracy: 0.7980
# Epoch 15/100
# 4112/4112 [==============================] - 0s 93us/sample - loss: 2.0989 - accuracy: 0.5136 - val_loss: 4.1507 - val_accuracy: 0.7819
# Epoch 16/100
# 4112/4112 [==============================] - 0s 96us/sample - loss: 1.7332 - accuracy: 0.4871 - val_loss: 3.1377 - val_accuracy: 0.6915
# Epoch 17/100
# 4112/4112 [==============================] - 0s 95us/sample - loss: 1.8602 - accuracy: 0.4964 - val_loss: 3.2238 - val_accuracy: 0.6973
# Epoch 18/100
# 4112/4112 [==============================] - 0s 96us/sample - loss: 2.0308 - accuracy: 0.4944 - val_loss: 3.4622 - val_accuracy: 0.7104
# Epoch 19/100
# 4112/4112 [==============================] - 0s 102us/sample - loss: 1.8940 - accuracy: 0.5209 - val_loss: 3.4346 - val_accuracy: 0.7236
# Epoch 20/100
# 4112/4112 [==============================] - 0s 100us/sample - loss: 1.8218 - accuracy: 0.5182 - val_loss: 3.2352 - val_accuracy: 0.7243
# Epoch 21/100
# 4112/4112 [==============================] - 0s 99us/sample - loss: 1.7409 - accuracy: 0.5146 - val_loss: 2.9641 - val_accuracy: 0.7112
# Epoch 22/100
# 4112/4112 [==============================] - 0s 101us/sample - loss: 1.6943 - accuracy: 0.5214 - val_loss: 2.9825 - val_accuracy: 0.7163
# Epoch 23/100
# 4112/4112 [==============================] - 0s 98us/sample - loss: 1.8243 - accuracy: 0.5248 - val_loss: 3.4545 - val_accuracy: 0.7360
# Epoch 24/100
# 4112/4112 [==============================] - 0s 103us/sample - loss: 2.0792 - accuracy: 0.5287 - val_loss: 3.7505 - val_accuracy: 0.7469
# Epoch 25/100
# 4112/4112 [==============================] - 0s 103us/sample - loss: 1.6343 - accuracy: 0.5460 - val_loss: 3.8628 - val_accuracy: 0.7535
# Epoch 26/100
# 4112/4112 [==============================] - 0s 103us/sample - loss: 1.8155 - accuracy: 0.5547 - val_loss: 3.0191 - val_accuracy: 0.7257
# Epoch 27/100
# 4112/4112 [==============================] - 0s 101us/sample - loss: 1.6554 - accuracy: 0.5491 - val_loss: 2.4437 - val_accuracy: 0.6834
# Epoch 28/100
# 4112/4112 [==============================] - 0s 103us/sample - loss: 1.5174 - accuracy: 0.5435 - val_loss: 2.9638 - val_accuracy: 0.7199
# Epoch 29/100
# 4112/4112 [==============================] - 0s 100us/sample - loss: 1.7026 - accuracy: 0.5477 - val_loss: 3.1461 - val_accuracy: 0.7199
# Epoch 30/100
# 4112/4112 [==============================] - 0s 93us/sample - loss: 1.8512 - accuracy: 0.5540 - val_loss: 2.7167 - val_accuracy: 0.6878
# Epoch 31/100
# 4112/4112 [==============================] - 0s 94us/sample - loss: 1.7078 - accuracy: 0.5199 - val_loss: 3.3284 - val_accuracy: 0.5770
# Epoch 32/100
# 4112/4112 [==============================] - 0s 93us/sample - loss: 1.7295 - accuracy: 0.4852 - val_loss: 2.6363 - val_accuracy: 0.5434
# Epoch 33/100
# 4112/4112 [==============================] - 0s 94us/sample - loss: 1.6959 - accuracy: 0.4876 - val_loss: 2.2166 - val_accuracy: 0.5419
# Epoch 34/100
# 4112/4112 [==============================] - 0s 103us/sample - loss: 1.6373 - accuracy: 0.4949 - val_loss: 2.1910 - val_accuracy: 0.5616
# Epoch 35/100
# 4112/4112 [==============================] - 0s 95us/sample - loss: 1.6430 - accuracy: 0.5071 - val_loss: 2.1326 - val_accuracy: 0.5711
# Epoch 36/100
# 4112/4112 [==============================] - 0s 94us/sample - loss: 1.5715 - accuracy: 0.5100 - val_loss: 2.2144 - val_accuracy: 0.6010
# Epoch 37/100
# 4112/4112 [==============================] - 0s 98us/sample - loss: 1.5359 - accuracy: 0.5253 - val_loss: 2.0686 - val_accuracy: 0.6076
# Epoch 38/100
# 4112/4112 [==============================] - 0s 95us/sample - loss: 1.6802 - accuracy: 0.5219 - val_loss: 2.0515 - val_accuracy: 0.6236
# Epoch 39/100
# 4112/4112 [==============================] - 0s 99us/sample - loss: 1.6291 - accuracy: 0.5353 - val_loss: 2.2452 - val_accuracy: 0.6521
# Epoch 40/100
# 4112/4112 [==============================] - 0s 101us/sample - loss: 1.7312 - accuracy: 0.5467 - val_loss: 2.4732 - val_accuracy: 0.6827
# Epoch 41/100
# 4112/4112 [==============================] - 0s 103us/sample - loss: 1.8106 - accuracy: 0.5508 - val_loss: 1.8478 - val_accuracy: 0.6324
# Epoch 42/100
# 4112/4112 [==============================] - 0s 108us/sample - loss: 1.7038 - accuracy: 0.5438 - val_loss: 1.7648 - val_accuracy: 0.6134
# Epoch 43/100
# 4112/4112 [==============================] - 0s 96us/sample - loss: 1.5065 - accuracy: 0.5433 - val_loss: 2.0884 - val_accuracy: 0.6601
# Epoch 44/100
# 4112/4112 [==============================] - 0s 93us/sample - loss: 1.5161 - accuracy: 0.5528 - val_loss: 2.1907 - val_accuracy: 0.6674
# Epoch 45/100
# 4112/4112 [==============================] - 0s 93us/sample - loss: 1.6971 - accuracy: 0.5562 - val_loss: 2.1886 - val_accuracy: 0.6769
# Epoch 46/100
# 4112/4112 [==============================] - 0s 94us/sample - loss: 1.4877 - accuracy: 0.5576 - val_loss: 1.7235 - val_accuracy: 0.6492
# Epoch 47/100
# 4112/4112 [==============================] - 0s 101us/sample - loss: 1.7125 - accuracy: 0.5598 - val_loss: 1.8960 - val_accuracy: 0.6616
# Epoch 48/100
# 4112/4112 [==============================] - 0s 95us/sample - loss: 1.5819 - accuracy: 0.5608 - val_loss: 2.0061 - val_accuracy: 0.6630
# Epoch 49/100
# 4112/4112 [==============================] - 0s 100us/sample - loss: 1.6627 - accuracy: 0.5674 - val_loss: 2.1527 - val_accuracy: 0.6842
# Epoch 50/100
# 4112/4112 [==============================] - 0s 100us/sample - loss: 1.6889 - accuracy: 0.5749 - val_loss: 3.0334 - val_accuracy: 0.7185
# Epoch 51/100
# 4112/4112 [==============================] - 0s 92us/sample - loss: 1.5867 - accuracy: 0.5664 - val_loss: 2.1071 - val_accuracy: 0.6652
# Epoch 52/100
# 4112/4112 [==============================] - 0s 98us/sample - loss: 1.5369 - accuracy: 0.5625 - val_loss: 1.6949 - val_accuracy: 0.5945
# Epoch 53/100
# 4112/4112 [==============================] - 0s 98us/sample - loss: 1.6410 - accuracy: 0.5564 - val_loss: 1.7152 - val_accuracy: 0.6047
# Epoch 54/100
# 4112/4112 [==============================] - 0s 101us/sample - loss: 1.5642 - accuracy: 0.5686 - val_loss: 2.0708 - val_accuracy: 0.6521
# Epoch 55/100
# 4112/4112 [==============================] - 0s 95us/sample - loss: 1.5197 - accuracy: 0.5751 - val_loss: 1.6552 - val_accuracy: 0.6346
# Epoch 56/100
# 4112/4112 [==============================] - 0s 99us/sample - loss: 1.5435 - accuracy: 0.5773 - val_loss: 1.7548 - val_accuracy: 0.6601
# Epoch 57/100
# 4112/4112 [==============================] - 0s 96us/sample - loss: 1.4522 - accuracy: 0.5805 - val_loss: 2.2918 - val_accuracy: 0.7039
# Epoch 58/100
# 4112/4112 [==============================] - 0s 104us/sample - loss: 1.5107 - accuracy: 0.5902 - val_loss: 1.9885 - val_accuracy: 0.6958
# Epoch 59/100
# 4112/4112 [==============================] - 0s 100us/sample - loss: 1.5688 - accuracy: 0.5924 - val_loss: 1.7795 - val_accuracy: 0.6849
# Epoch 60/100
# 4112/4112 [==============================] - 0s 102us/sample - loss: 1.5564 - accuracy: 0.5817 - val_loss: 1.5348 - val_accuracy: 0.5872
# Epoch 61/100
# 4112/4112 [==============================] - 0s 103us/sample - loss: 1.4763 - accuracy: 0.5824 - val_loss: 1.8386 - val_accuracy: 0.6477
# Epoch 62/100
# 4112/4112 [==============================] - 0s 94us/sample - loss: 1.7112 - accuracy: 0.5834 - val_loss: 2.1128 - val_accuracy: 0.6667
# Epoch 63/100
# 4112/4112 [==============================] - 0s 95us/sample - loss: 1.7132 - accuracy: 0.5854 - val_loss: 2.3474 - val_accuracy: 0.6769
# Epoch 64/100
# 4112/4112 [==============================] - 0s 101us/sample - loss: 1.7605 - accuracy: 0.5851 - val_loss: 1.8561 - val_accuracy: 0.6550
# Epoch 65/100
# 4112/4112 [==============================] - 0s 98us/sample - loss: 1.6763 - accuracy: 0.5788 - val_loss: 2.1286 - val_accuracy: 0.6842
# Epoch 66/100
# 4112/4112 [==============================] - 0s 103us/sample - loss: 1.5302 - accuracy: 0.5875 - val_loss: 1.9100 - val_accuracy: 0.6710
# Epoch 67/100
# 4112/4112 [==============================] - 0s 101us/sample - loss: 1.5189 - accuracy: 0.5868 - val_loss: 1.7383 - val_accuracy: 0.6630
# Epoch 68/100
# 4112/4112 [==============================] - 0s 99us/sample - loss: 1.6979 - accuracy: 0.5837 - val_loss: 2.0945 - val_accuracy: 0.6878
# Epoch 69/100
# 4112/4112 [==============================] - 0s 93us/sample - loss: 1.3702 - accuracy: 0.5851 - val_loss: 2.6383 - val_accuracy: 0.7206
# Epoch 70/100
# 4112/4112 [==============================] - 0s 105us/sample - loss: 1.6830 - accuracy: 0.6007 - val_loss: 2.2305 - val_accuracy: 0.6951
# Epoch 71/100
# 4112/4112 [==============================] - 0s 96us/sample - loss: 1.4673 - accuracy: 0.5837 - val_loss: 1.9924 - val_accuracy: 0.6616
# Epoch 72/100
# 4112/4112 [==============================] - 0s 101us/sample - loss: 1.4820 - accuracy: 0.5893 - val_loss: 1.8978 - val_accuracy: 0.6623
# Epoch 73/100
# 4112/4112 [==============================] - 0s 94us/sample - loss: 1.4177 - accuracy: 0.5946 - val_loss: 1.8585 - val_accuracy: 0.6667
# Epoch 74/100
# 4112/4112 [==============================] - 0s 103us/sample - loss: 1.4374 - accuracy: 0.6007 - val_loss: 1.9782 - val_accuracy: 0.6776
# Epoch 75/100
# 4112/4112 [==============================] - 0s 98us/sample - loss: 1.4995 - accuracy: 0.6065 - val_loss: 2.1846 - val_accuracy: 0.7119
# Epoch 76/100
# 4112/4112 [==============================] - 0s 107us/sample - loss: 1.6753 - accuracy: 0.6002 - val_loss: 3.0728 - val_accuracy: 0.6244
# Epoch 77/100
# 4112/4112 [==============================] - 0s 103us/sample - loss: 1.7547 - accuracy: 0.5824 - val_loss: 2.8157 - val_accuracy: 0.6061
# Epoch 78/100
# 4112/4112 [==============================] - 0s 111us/sample - loss: 1.7083 - accuracy: 0.5824 - val_loss: 3.0232 - val_accuracy: 0.6054
# Epoch 79/100
# 4112/4112 [==============================] - 0s 108us/sample - loss: 1.4230 - accuracy: 0.5820 - val_loss: 3.1507 - val_accuracy: 0.6295
# Epoch 80/100
# 4112/4112 [==============================] - 0s 103us/sample - loss: 1.5142 - accuracy: 0.5868 - val_loss: 3.0947 - val_accuracy: 0.6470
# Epoch 81/100
# 4112/4112 [==============================] - 0s 96us/sample - loss: 1.5219 - accuracy: 0.5900 - val_loss: 2.7673 - val_accuracy: 0.6630
# Epoch 82/100
# 4112/4112 [==============================] - 0s 106us/sample - loss: 1.4514 - accuracy: 0.5941 - val_loss: 2.4330 - val_accuracy: 0.6543
# Epoch 83/100
# 4112/4112 [==============================] - 0s 106us/sample - loss: 1.4634 - accuracy: 0.5985 - val_loss: 2.3146 - val_accuracy: 0.6543
# Epoch 84/100
# 4112/4112 [==============================] - 0s 107us/sample - loss: 1.5293 - accuracy: 0.5975 - val_loss: 2.5203 - val_accuracy: 0.6710
# Epoch 85/100
# 4112/4112 [==============================] - 0s 106us/sample - loss: 1.4918 - accuracy: 0.5893 - val_loss: 4.0262 - val_accuracy: 0.7031
# Epoch 86/100
# 4112/4112 [==============================] - 0s 107us/sample - loss: 1.6281 - accuracy: 0.5764 - val_loss: 2.9431 - val_accuracy: 0.7170
# Epoch 87/100
# 4112/4112 [==============================] - 0s 107us/sample - loss: 1.6581 - accuracy: 0.5854 - val_loss: 1.7652 - val_accuracy: 0.6608
# Epoch 88/100
# 4112/4112 [==============================] - 0s 101us/sample - loss: 1.5637 - accuracy: 0.5627 - val_loss: 1.6786 - val_accuracy: 0.6134
# Epoch 89/100
# 4112/4112 [==============================] - 0s 105us/sample - loss: 1.4973 - accuracy: 0.5554 - val_loss: 1.6733 - val_accuracy: 0.6295
# Epoch 90/100
# 4112/4112 [==============================] - 0s 111us/sample - loss: 1.5053 - accuracy: 0.5635 - val_loss: 1.8261 - val_accuracy: 0.6557
# Epoch 91/100
# 4112/4112 [==============================] - 0s 106us/sample - loss: 1.4369 - accuracy: 0.5829 - val_loss: 2.1883 - val_accuracy: 0.7017
# Epoch 92/100
# 4112/4112 [==============================] - 0s 106us/sample - loss: 1.3954 - accuracy: 0.5880 - val_loss: 2.4066 - val_accuracy: 0.7279
# Epoch 93/100
# 4112/4112 [==============================] - 0s 97us/sample - loss: 1.4127 - accuracy: 0.6009 - val_loss: 2.5459 - val_accuracy: 0.7433
# Epoch 94/100
# 4112/4112 [==============================] - 0s 99us/sample - loss: 1.4417 - accuracy: 0.6065 - val_loss: 2.4550 - val_accuracy: 0.7243
# Epoch 95/100
# 4112/4112 [==============================] - 0s 99us/sample - loss: 1.4486 - accuracy: 0.6099 - val_loss: 2.7005 - val_accuracy: 0.7316
# Epoch 96/100
# 4112/4112 [==============================] - 0s 98us/sample - loss: 1.5416 - accuracy: 0.6116 - val_loss: 2.0024 - val_accuracy: 0.6805
# Epoch 97/100
# 4112/4112 [==============================] - 0s 99us/sample - loss: 1.4092 - accuracy: 0.5936 - val_loss: 1.7589 - val_accuracy: 0.6565
# Epoch 98/100
# 4112/4112 [==============================] - 0s 101us/sample - loss: 1.4790 - accuracy: 0.6068 - val_loss: 1.8471 - val_accuracy: 0.6849
# Epoch 99/100
# 4112/4112 [==============================] - 0s 106us/sample - loss: 1.2936 - accuracy: 0.6141 - val_loss: 2.0541 - val_accuracy: 0.6988
# Epoch 100/100
# 4112/4112 [==============================] - 0s 98us/sample - loss: 1.4024 - accuracy: 0.6231 - val_loss: 1.9652 - val_accuracy: 0.7039

# %%
sns.set()

for graph in ['loss', 'accuracy']:
    
    plt.plot(model_history[graph], linewidth=2, label='Train')
    plt.plot(model_history['val_'+graph], linewidth=2, label='Valid')
    
    plt.legend(loc='upper left')
    plt.title('Model '+graph)
    plt.ylabel(graph)
    plt.xlabel('Epoch')
    
    plt.show()

# %%
#Model Evaluation
high_risk_real_value = -5.0
low_risk_real_value  = -6.0001
classification_threshold = 0.973

def evaluate(name, y_pred):
    
    #rescaling data
    y_test_scaled = y_scaler.inverse_transform(y_test_numeric)
    
    #getting numeric predictions from boolean predictions
    y_pred_numeric = np.zeros((y_pred.shape[0],y_pred.shape[1]))
    y_pred_numeric[y_pred==True] = high_risk_real_value
    y_pred_numeric[y_pred==False] = low_risk_real_value
    
    #getting predictions greater than -6.0 in real data (y_test_scaled)
    y_pred_mse = y_pred_numeric[np.where(y_test_scaled >= -6.0)]
    y_test_mse = y_test_scaled[np.where(y_test_scaled >= -6.0)]
    
    mse = mean_squared_error(y_test_mse, y_pred_mse)
    
    y_real_bool = (y_test_scaled >= -6.0).reshape(-1,1)
    
    f_beta = fbeta_score(y_real_bool, y_pred, 2)
    score = mse / f_beta
    print(name, "{:0.3f}, {:0.3f}, {:0.3f}".format(score, mse, f_beta))
        
    hm = sns.heatmap(confusion_matrix(y_real_bool, y_pred), annot=True, cmap="Blues", fmt='d')# font size
    bottom, top = hm.get_ylim()
    hm.set_ylim(bottom + 0.5, top - 0.5)
    plt.show()

#Predicting with model
y_model = model.predict(X_test, batch_size=batch)
plt.hist(y_model, bins=30)
plt.show()
y_model = (y_model > classification_threshold).reshape(-1,1)
evaluate("LSTM model:", y_model)

#Predicting -5 always
y_constant = np.ones((y_test.shape[0],y_test.shape[1]), dtype=bool)
evaluate("Constant prediction:", y_constant)

#Predicting last value
y_last = X_test[:,-1,1]
tmp = np.array([-6]).reshape(-1,1)
tmp = y_scaler.transform(tmp)
tmp = tmp[0,0]
y_last = (y_last > tmp).reshape(-1,1)
evaluate("Predicting last value:", y_last)
# Out:
# LSTM model: 0.429, 0.186, 0.433
# Constant prediction: 6.819, 0.340, 0.050
# Predicting last value: 0.600, 0.372, 0.620

# %%
#Predicting last value
def recurrent_evaluate(name, y_pred):
    
    #Scaling both real predicted
    y_pred_scaled = y_scaler.inverse_transform(y_pred)
    y_real_scaled = y_scaler.inverse_transform(y_test_numeric)
    
    #boolean data
    y_pred_bool = (y_pred_scaled >= -6.0).reshape(-1,1)
    y_real_bool = (y_real_scaled >= -6.0).reshape(-1,1)
    f_beta = fbeta_score(y_real_bool, y_pred_bool, 2)
    
    #getting predictions greater than -6.0 in real data (y_real_scaled)
    y_pred_mse = y_pred_scaled[np.where(y_real_scaled >= -6.0)]
    y_real_mse = y_real_scaled[np.where(y_real_scaled >= -6.0)]
    mse = mean_squared_error(y_real_mse, y_pred_mse)
    
    #F-beta score
    score = mse / f_beta
    print(name, "{:0.3f}, {:0.3f}, {:0.3f}".format(score, mse, f_beta))
        
    #Confusion matrix
    hm = sns.heatmap(confusion_matrix(y_real_bool, y_pred_bool), annot=True, cmap="Blues", fmt='d')# font size
    bottom, top = hm.get_ylim()
    hm.set_ylim(bottom + 0.5, top - 0.5)
    plt.show()

    
y_last = X_test[:,-1,1].reshape(-1,1)
y_bool_2 = recurrent_evaluate("Predicting last value:", y_last)
# Out:
# Predicting last value: 15.029, 9.324, 0.620
